# %% [markdown]
# ![Imagen](itd.png)
#
# # Analisis De Datos Masivos
# ## Introduccion A DataFrames En Pandas
#
# ## Nombre Del Docente
# ### Jose Gabriel Rodriguez Rivas
#
# ## Francisco javier Favela Najera

# %% [markdown]
# ## Tabla De Contenido
# [1-.Introduccion A **Dataframes** En Pandas](#id1)<br>
# [2-.Indexing DataFrame](#id2)<br>
# [3-.Tranpuesta](#id3)<br>
# [4-Copiar DataFrame](#id4)<br>
# [5-Loading CSV as DataFrame](#id5)<br>
# [6-Busqueda en un DataFrame](#id6)<br>
# [7-Group By DataFrame](#id7)<br>

# %% [markdown]
# ## Introducccion A Dataframes<a id='id1'></a>

# %%
import pandas as pd

# %%
alumnos1=pd.Series({'Nombre':'Juan','Fecha Nacimiento':'10-02-2000','carrera':'IING','Edad':20})
alumnos2=pd.Series({'Nombre':'Pedro','Fecha Nacimiento':'11-04-2005','carrera':'ISC','Edad':15})
alumnos3=pd.Series({'Nombre':'Isabel','Fecha Nacimiento':'02-02-2002','carrera':'ISC','Edad':18})
alumnos4=pd.Series({'Nombre':'Jose','Fecha Nacimiento':'09-05-2001','carrera':'ISC','Edad':19})

# %%
Alumnos=pd.DataFrame(list((alumnos1, alumnos2,alumnos3,alumnos4)))

# %%
Alumnos
# Out:
#    Nombre Fecha Nacimiento carrera  Edad
# 0    Juan       10-02-2000    IING    20
# 1   Pedro       11-04-2005     ISC    15
# 2  Isabel       02-02-2002     ISC    18
# 3    Jose       09-05-2001     ISC    19

# %% [markdown]
# ## Indexing DataFrame<a id='id2'></a>

# %%
Alumnos.iloc[1]
# Out:
# Nombre                   Pedro
# Fecha Nacimiento    11-04-2005
# carrera                    ISC
# Edad                        15
# Name: 1, dtype: object

# %%
Alumnos=Alumnos.set_index(carrera)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-ef8adc8b51b8> in <module>
# ----> 1 Alumnos=Alumnos.set_index(carrera)
#
# NameError: name 'carrera' is not defined

# %% [markdown]
# ## Tranpuesta <a id='id3'></a>

# %%
Alumnos.T
# Out:
#                            0           1           2           3
# Nombre                  Juan       Pedro      Isabel        Jose
# Fecha Nacimiento  10-02-2000  11-04-2005  02-02-2002  09-05-2001
# carrera                 IING         ISC         ISC         ISC
# Edad                      20          15          18          19

# %%
Alumnos['carrera']=Alumnos.index
Alumnos=Alumnos.set_index('Nombre')
Alumnos
# Out:
#        Fecha Nacimiento  carrera  Edad
# Nombre
# Juan         10-02-2000        0    20
# Pedro        11-04-2005        1    15
# Isabel       02-02-2002        2    18
# Jose         09-05-2001        3    19

# %%
Alumnos.reset_index()
# Out:
#    Nombre Fecha Nacimiento  carrera  Edad
# 0    Juan       10-02-2000        0    20
# 1   Pedro       11-04-2005        1    15
# 2  Isabel       02-02-2002        2    18
# 3    Jose       09-05-2001        3    19

# %% [markdown]
# ## Copiar dataframes<a id='id4'></a>

# %%
copia_Alumnos=Alumnos.copy()
copia_Alumnos
# Out:
#        Fecha Nacimiento  carrera  Edad
# Nombre
# Juan         10-02-2000        0    20
# Pedro        11-04-2005        1    15
# Isabel       02-02-2002        2    18
# Jose         09-05-2001        3    19

# %% [markdown]
# ## Loading CSV as DataFrame <a id='id5'></a>

# %%
df=pd.read_csv('olympics.csv')
df
# Out:
#                                                 0         1     2     3     4  \
# 0                                             NaN  № Summer  01 !  02 !  03 !
# 1                               Afghanistan (AFG)        13     0     0     2
# 2                                   Algeria (ALG)        12     5     2     8
# 3                                 Argentina (ARG)        23    18    24    28
# 4                                   Armenia (ARM)         5     1     2     9
# 5                         Australasia (ANZ) [ANZ]         2     3     4     5
# 6                       Australia (AUS) [AUS] [Z]        25   139   152   177
# 7                                   Austria (AUT)        26    18    33    35
# 8                                Azerbaijan (AZE)         5     6     5    15
# 9                                   Bahamas (BAH)        15     5     2     5
# 10                                  Bahrain (BRN)         8     0     0     1
# ...

# %%
df.head(15)
# Out:
#                             0         1     2     3     4      5         6  \
# 0                         NaN  № Summer  01 !  02 !  03 !  Total  № Winter
# 1           Afghanistan (AFG)        13     0     0     2      2         0
# 2               Algeria (ALG)        12     5     2     8     15         3
# 3             Argentina (ARG)        23    18    24    28     70        18
# 4               Armenia (ARM)         5     1     2     9     12         6
# 5     Australasia (ANZ) [ANZ]         2     3     4     5     12         0
# 6   Australia (AUS) [AUS] [Z]        25   139   152   177    468        18
# 7               Austria (AUT)        26    18    33    35     86        22
# 8            Azerbaijan (AZE)         5     6     5    15     26         5
# 9               Bahamas (BAH)        15     5     2     5     12         0
# 10              Bahrain (BRN)         8     0     0     1      1         0
# ...

# %%
df=pd.read_csv('olympics.csv',index_col=0,skiprows=1)
df
# Out:
#                                               № Summer  01 !  02 !  03 !  \
# Afghanistan (AFG)                                   13     0     0     2
# Algeria (ALG)                                       12     5     2     8
# Argentina (ARG)                                     23    18    24    28
# Armenia (ARM)                                        5     1     2     9
# Australasia (ANZ) [ANZ]                              2     3     4     5
# Australia (AUS) [AUS] [Z]                           25   139   152   177
# Austria (AUT)                                       26    18    33    35
# Azerbaijan (AZE)                                     5     6     5    15
# Bahamas (BAH)                                       15     5     2     5
# Bahrain (BRN)                                        8     0     0     1
# Barbados (BAR) [BAR]                                11     0     0     1
# Belarus (BLR)                                        5    12    24    39
# ...

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
df.loc['Algeria']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Algeria'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f813a0f4446f> in <module>
# ----> 1 df.loc['Algeria']
#
# ...

# %%
y='01'
x=y[4:]
x
# Out:
# ''

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold' + col[4:]},inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver' + col[4:]},inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze' + col[4:]},inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#' + col[1:]},inplace=True)

# %%
df.columns
# Out:
# Index(['# Summer', 'Gold', 'Silver', 'Bronze', 'Total', '# Winter', 'Gold.1',
#        'Silver.1', 'Bronze.1', 'Total.1', '# Games', 'Gold.2', 'Silver.2',
#        'Bronze.2', 'Combined total'],
#       dtype='object')

# %% [markdown]
# ## Busquedas En DataFrames<a id='id6'></a>

# %%
df.head(10)
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)                13     0       0       2      2         0
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
# Austria (AUT)                    26    18      33      35     86        22
# Azerbaijan (AZE)                  5     6       5      15     26         5
# Bahamas (BAH)                    15     5       2       5     12         0
# Bahrain (BRN)                     8     0       0       1      1         0
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# ...

# %%
df['Gold'].head(10)>0
# Out:
# Afghanistan (AFG)            False
# Algeria (ALG)                 True
# Argentina (ARG)               True
# Armenia (ARM)                 True
# Australasia (ANZ) [ANZ]       True
# Australia (AUS) [AUS] [Z]     True
# Austria (AUT)                 True
# Azerbaijan (AZE)              True
# Bahamas (BAH)                 True
# Bahrain (BRN)                False
# Name: Gold, dtype: bool

# %%
ganadores_oro=df.where(df['Gold']>0).dropna()
ganadores_oro
# Out:
#                                      # Summer    Gold  Silver  Bronze  \
# Algeria (ALG)                            12.0     5.0     2.0     8.0
# Argentina (ARG)                          23.0    18.0    24.0    28.0
# Armenia (ARM)                             5.0     1.0     2.0     9.0
# Australasia (ANZ) [ANZ]                   2.0     3.0     4.0     5.0
# Australia (AUS) [AUS] [Z]                25.0   139.0   152.0   177.0
# Austria (AUT)                            26.0    18.0    33.0    35.0
# Azerbaijan (AZE)                          5.0     6.0     5.0    15.0
# Bahamas (BAH)                            15.0     5.0     2.0     5.0
# Belarus (BLR)                             5.0    12.0    24.0    39.0
# Belgium (BEL)                            25.0    37.0    52.0    53.0
# Brazil (BRA)                             21.0    23.0    30.0    55.0
# Bulgaria (BUL) [H]                       19.0    51.0    85.0    78.0
# ...

# %%
ganadores_oro['Gold'].count()
# Out:
# 100

# %%
df['Gold'].count()
# Out:
# 147

# %%
ganadores_oro=ganadores_oro.dropna()

# %%
ganadores_oro
# Out:
#                                      # Summer    Gold  Silver  Bronze  \
# Algeria (ALG)                            12.0     5.0     2.0     8.0
# Argentina (ARG)                          23.0    18.0    24.0    28.0
# Armenia (ARM)                             5.0     1.0     2.0     9.0
# Australasia (ANZ) [ANZ]                   2.0     3.0     4.0     5.0
# Australia (AUS) [AUS] [Z]                25.0   139.0   152.0   177.0
# Austria (AUT)                            26.0    18.0    33.0    35.0
# Azerbaijan (AZE)                          5.0     6.0     5.0    15.0
# Bahamas (BAH)                            15.0     5.0     2.0     5.0
# Belarus (BLR)                             5.0    12.0    24.0    39.0
# Belgium (BEL)                            25.0    37.0    52.0    53.0
# Brazil (BRA)                             21.0    23.0    30.0    55.0
# Bulgaria (BUL) [H]                       19.0    51.0    85.0    78.0
# ...

# %%
ganadores_oro2=df[df['Gold']>0]
ganadores_oro2
# Out:
#                                      # Summer  Gold  Silver  Bronze  Total  \
# Algeria (ALG)                              12     5       2       8     15
# Argentina (ARG)                            23    18      24      28     70
# Armenia (ARM)                               5     1       2       9     12
# Australasia (ANZ) [ANZ]                     2     3       4       5     12
# Australia (AUS) [AUS] [Z]                  25   139     152     177    468
# Austria (AUT)                              26    18      33      35     86
# Azerbaijan (AZE)                            5     6       5      15     26
# Bahamas (BAH)                              15     5       2       5     12
# Belarus (BLR)                               5    12      24      39     75
# Belgium (BEL)                              25    37      52      53    142
# Brazil (BRA)                               21    23      30      55    108
# ...

# %%
ganadores_oro3=df[(df['Gold']>0) | (df['Gold.1']>0)]
ganadores_oro3
# Out:
#                                      # Summer  Gold  Silver  Bronze  Total  \
# Algeria (ALG)                              12     5       2       8     15
# Argentina (ARG)                            23    18      24      28     70
# Armenia (ARM)                               5     1       2       9     12
# Australasia (ANZ) [ANZ]                     2     3       4       5     12
# Australia (AUS) [AUS] [Z]                  25   139     152     177    468
# Austria (AUT)                              26    18      33      35     86
# Azerbaijan (AZE)                            5     6       5      15     26
# Bahamas (BAH)                              15     5       2       5     12
# Belarus (BLR)                               5    12      24      39     75
# Belgium (BEL)                              25    37      52      53    142
# Brazil (BRA)                               21    23      30      55    108
# ...

# %%
columnas=[
    '# Winter',
    'Gold.1',
    'Silver.1',
    'Bronze.1',
    'Total.1'
]
invierno=df[columnas]
invierno.head()
# Out:
#                          # Winter  Gold.1  Silver.1  Bronze.1  Total.1
# Afghanistan (AFG)               0       0         0         0        0
# Algeria (ALG)                   3       0         0         0        0
# Argentina (ARG)                18       0         0         0        0
# Armenia (ARM)                   6       0         0         0        0
# Australasia (ANZ) [ANZ]         0       0         0         0        0

# %% [markdown]
# ## Preparación de datos<a id='id7'></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %%
# code cell 2
# This should be a local path
dataset_path = 'Map-Crime_Incidents-Previous_Three_Months.csv'

# read the original dataset (in comma separated values format) into a DataFrame
SF = pd.read_csv(dataset_path)

# %%
len(SF)
# Out:
# 30760

# %%
SF['Month'] = SF['Date'].apply(lambda row: int(row[0:2]))
SF['Day'] = SF['Date'].apply(lambda row: int(row[3:5]))

# %%
SF.head()
# Out:
#         Category                        Descript DayOfWeek  \
# 0  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  Month  Day
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974      8   31
# 1  COLUMBUS AV / JACKSON ST -122.404418  37.796302      8   31
# ...

# %%
del SF['IncidntNum']

# %%
SF.drop('Location',axis=1,inplace=True)

# %% [markdown]
# ## pregunta de desafío: ¿Qué PdDistrict presentaba la mayoría de los incidentes de delitos informados? Proporcione los comandos de Python utilizados para respaldar su respuesta.

# %%
concatCategorias=SF['Category'].value_counts()
concatCategorias.tail(10)
# Out:
# SUICIDE                       14
# FAMILY OFFENSES                9
# STOLEN PROPERTY                7
# EXTORTION                      7
# SEX OFFENSES, NON FORCIBLE     5
# LOITERING                      5
# BAD CHECKS                     3
# GAMBLING                       1
# BRIBERY                        1
# PORNOGRAPHY/OBSCENE MAT        1
# Name: Category, dtype: int64

# %%
concatCategorias=SF['PdDistrict'].value_counts()
concatCategorias.head(1)
# Out:
# SOUTHERN    6185
# Name: PdDistrict, dtype: int64

# %% [markdown]
# ## Crear subconjuntos de datos y organizarlos en marcos de datos más pequeños

# %%
AugustCrimes = SF[SF['Month'] == 8]
AugustCrimes
# Out:
#                          Category  \
# 0                   LARCENY/THEFT
# 1                   LARCENY/THEFT
# 2                   LARCENY/THEFT
# 3                   DRUG/NARCOTIC
# 4                   DRUG/NARCOTIC
# 5                   LARCENY/THEFT
# 6                        WARRANTS
# 7                   VEHICLE THEFT
# 8                   LARCENY/THEFT
# 9                         ROBBERY
# 10                   NON-CRIMINAL
# 11                  VEHICLE THEFT
# 12                       TRESPASS
# 13                  LARCENY/THEFT
# 14                   NON-CRIMINAL
# 15                   NON-CRIMINAL
# 16                   NON-CRIMINAL
# 17                   NON-CRIMINAL
# 18                      VANDALISM
# 19                   NON-CRIMINAL
# 20                        ASSAULT
# 21                  LARCENY/THEFT
# 22                  DRUG/NARCOTIC
# 23                  LARCENY/THEFT
# 24                  LARCENY/THEFT
# 25                  LARCENY/THEFT
# ...

# %% [markdown]
# ¿Cuántos incidentes de delitos hubo en agosto?

# %%
len(AugustCrimes)
# Out:
# 9720

# %%
AugustCrimes=SF[SF['Category']== 'LARCENY/THEFT' | SF['Category']== 'VEHICLE THEFT']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in ror_(left, right)
#     190 def ror_(left, right):
# --> 191     return operator.or_(right, left)
#     192
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1803                 try:
# -> 1804                     result = libops.scalar_binop(x, y, op)
#    1805                 except (TypeError, ValueError, AttributeError,
#
# ...

# %%
# crimes agosto
crimenes0105=SF.query('Month== 8 and Day== 1')
crimenes0105.head()
# Out:
#             Category                                         Descript  \
# 9356        BURGLARY                         BURGLARY, FORCIBLE ENTRY
# 9357  OTHER OFFENSES                         TRAFFIC VIOLATION ARREST
# 9358  OTHER OFFENSES                              PROBATION VIOLATION
# 9359     WEAPON LAWS                           POSS OF LOADED FIREARM
# 9360     WEAPON LAWS  POSS OF FIREARM BY CONVICTED FELON/ADDICT/ALIEN
#
#      DayOfWeek                          Date   Time PdDistrict  \
# 9356    Friday  08/01/2014 07:00:00 AM +0000  21:10   SOUTHERN
# 9357    Friday  08/01/2014 07:00:00 AM +0000  22:44    MISSION
# 9358    Friday  08/01/2014 07:00:00 AM +0000  22:44    MISSION
# 9359    Friday  08/01/2014 07:00:00 AM +0000  22:44    MISSION
# 9360    Friday  08/01/2014 07:00:00 AM +0000  22:44    MISSION
#
#           Resolution                   Address           X          Y  Month  \
# 9356            NONE  400.0 Block of BRYANT ST -122.395531  37.781523      8
# ...

# %% [markdown]
# ### Graficar Datos

# %%
plt.plot(SF['X'],SF['Y'], 'b*')
plt.show()

# %%
pd_districts = np.unique(SF['PdDistrict'])
pd_districts_levels = dict(zip(pd_districts, range(len(pd_districts))))
pd_districts_levels
# Out:
# {'BAYVIEW': 0,
#  'CENTRAL': 1,
#  'INGLESIDE': 2,
#  'MISSION': 3,
#  'NORTHERN': 4,
#  'PARK': 5,
#  'RICHMOND': 6,
#  'SOUTHERN': 7,
#  'TARAVAL': 8,
#  'TENDERLOIN': 9}

# %%
SF['PdDistrictCode'] = SF['PdDistrict'].apply(lambda row: pd_districts_levels[row])

# %%
plt.scatter(SF['X'], SF['Y'], c=SF['PdDistrictCode'])
plt.show()

# %%
s

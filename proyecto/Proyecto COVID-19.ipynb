# %% [markdown]
# ![](escudo.png)
# ## Proyecto COVID-19
# ### Docente:
# ### Jose Gabriel Rodriguez Rivas
# ### Alumnos:
# ###  Francisco Javier Favela Najera
# ### Jorge Alberto Hernandez Castro

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
plt.style.use('fivethirtyeight')

# %%
df_virus=pd.read_csv('200807COVID19MEXICO.csv', encoding = "ISO-8859-1")
#df_entidades=pd.read_csv('ENTIDADES.csv', encoding = "ISO-8859-1")
df_virus.shape[0]
# Out:
# 1048575

# %%
df_virus.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          07/08/2020      0f9404       2       3          25     1
# 1          07/08/2020      07b035       2       4           1     1
# 2          07/08/2020      08c8fb       2       4           9     2
# 3          07/08/2020      1a59f9       2       3          27     1
# 4          07/08/2020      023a88       2       4          26     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... CARDIOVASCULAR  \
# 0           11           25              6              2  ...              2
# 1            1            1              1              1  ...              2
# 2            9            9              2              2  ...              2
# 3           27           27              4              1  ...              2
# 4           25           26             55              2  ...              2
#
#   OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  \
# 0        2             2           2         99          1        99
# 1        2             2           2         99          1        99
# 2        2             2           2         99          1        99
# 3        2             2           2          1          1        99
# 4        2             2           2         99          1        99
#
#    PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0            MÃ©xico           99    2
# 1            MÃ©xico           99   97
# 2            MÃ©xico           99    2
# 3            MÃ©xico           99   97
# 4            MÃ©xico           99    2
#
# [5 rows x 35 columns]

# %%
df_virus.drop(['HABLA_LENGUA_INDIG','ENTIDAD_UM','FECHA_ACTUALIZACION','ID_REGISTRO','ENTIDAD_NAC','MIGRANTE',
               'PAIS_NACIONALIDAD','PAIS_ORIGEN','INTUBADO','UCI','OTRO_CASO'],axis=1,inplace=True)

# %%
df_virus.head()
# Out:
#    ORIGEN  SECTOR  SEXO  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 0       2       3     1           25              6              2
# 1       2       4     1            1              1              1
# 2       2       4     2            9              2              2
# 3       2       3     1           27              4              1
# 4       2       4     1           26             55              2
#
#   FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  NEUMONIA  ...  EPOC  ASMA  \
# 0    09/06/2020     06/06/2020  16/06/2020         1  ...     2     2
# 1    23/04/2020     13/04/2020  9999-99-99         2  ...     2     2
# 2    29/04/2020     22/04/2020  03/05/2020         1  ...     2     2
# 3    25/06/2020     20/06/2020  9999-99-99         1  ...     2     2
# 4    30/03/2020     27/03/2020  9999-99-99         1  ...     2     2
#
#    INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0         2             2         2               2         2              2
# 1         2             2         2               2         2              2
# 2         2             1         2               2         2              2
# 3         2             1         2               2         2              2
# 4         2             1         2               2         2              2
#
#    TABAQUISMO  RESULTADO
# 0           2          1
# 1           2          1
# 2           2          1
# 3           2          1
# 4           2          1
#
# [5 rows x 24 columns]

# %%
casos_positivos = df_virus=df_virus.loc[df_virus['RESULTADO'] == 1]

# %%
df_resultado_prueba = df_virus.groupby(['RESULTADO']).size().reset_index(name='Total')
df_resultado_prueba['RESULTADO'] = df_resultado_prueba['RESULTADO'].apply(lambda toLabel: 'POSITIVO' if toLabel==1 else
                                                                         'NEGATIVO' if toLabel ==2 else 'EN PROCESO')
df_resultado_prueba
# Out:
#   RESULTADO   Total
# 0  POSITIVO  469407

# %%
TotalR = pd.Series({'POSITIVO': 469407,
                      'NEGATIVO': 513144,
                      'EN PROCESO': 89155})
TotalR.plot(kind='bar', title='Casos Analizados')

# %%
Genero = casos_positivos['SEXO'].value_counts()
Genero
# Out:
# 2    248893
# 1    220514
# Name: SEXO, dtype: int64

# %%
porcentaje_genero = [100/469407*n for n in Genero]
print(porcentaje_genero)
# Out:
# [53.022856497666204, 46.977143502333796]

# %%
fig, ax = plt.subplots(1, figsize=(20, 7))

labels_genero = 'Hombres', 'Mujeres'

ax.pie(porcentaje_genero, labels=labels_genero, autopct='%1.2f%%')
ax.set_title('Porcentaje de hombres y mujeres positivos')
# Out:
# Text(0.5, 1.0, 'Porcentaje de hombres y mujeres positivos')

# %% [markdown]
# ## Enfermedades

# %% [markdown]
# ### Neumonia, Asma y Epoc

# %%
neumonia = casos_positivos['NEUMONIA'].value_counts()
neumonia
# Out:
# 2     374127
# 1      95275
# 99         5
# Name: NEUMONIA, dtype: int64

# %%
porcentaje_neumo = [100/469407*n for n in neumonia]
print(porcentaje_neumo)
# Out:
# [79.70204960727045, 20.296885219010367, 0.0010651737191818614]

# %%
asma = casos_positivos['ASMA'].value_counts()
asma
# Out:
# 2     455563
# 1      12512
# 98      1332
# Name: ASMA, dtype: int64

# %%
porcentaje_asma = [100/469407*n for n in asma]
print(porcentaje_asma)
# Out:
# [97.05074700632926, 2.66549071488069, 0.28376227879004784]

# %%
epoc = casos_positivos['EPOC'].value_counts()
epoc
# Out:
# 2     460769
# 1       7299
# 98      1339
# Name: EPOC, dtype: int64

# %%
porcentaje_epoc = [100/469407*n for n in epoc]
print(porcentaje_epoc)
# Out:
# [98.15980588274141, 1.5549405952616813, 0.28525352199690246]

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 15))

label_neumo = 'NEGATIVO', 'POSITIVO','NO ESPECIFICADO'
label_asma = 'NEGATIVO', 'POSITIVO','SE IGNORA'
label_epoc = 'NEGATIVO', 'POSITIVO','SE IGNORA'

ax[0].pie(porcentaje_neumo, labels=label_neumo, autopct='%1.2f%%') 
ax[0].set_title('NEUMONIA', fontsize=16)

ax[1].pie(porcentaje_asma, labels=label_asma, autopct='%1.2f%%')
ax[1].set_title('ASMA', fontsize=16)

ax[2].pie(porcentaje_epoc, labels=label_epoc, autopct='%1.2f%%')
ax[2].set_title('EPOC', fontsize=16)
# Out:
# Text(0.5, 1.0, 'EPOC')

# %% [markdown]
# ### Obesidad y Diabetes

# %%
obesidad = casos_positivos['OBESIDAD'].value_counts()
obesidad
# Out:
# 2     380164
# 1      87864
# 98      1379
# Name: OBESIDAD, dtype: int64

# %%
porcentaje_obesidad = [100/469407*n for n in obesidad]
print(porcentaje_obesidad)
# Out:
# [80.98814035581063, 18.718084732439014, 0.29377491175035736]

# %%
diabetes = casos_positivos['DIABETES'].value_counts()
diabetes
# Out:
# 2     393024
# 1      74881
# 98      1502
# Name: DIABETES, dtype: int64

# %%
porcentaje_diabetes = [100/469407*n for n in diabetes]
print(porcentaje_diabetes)
# Out:
# [83.72776716154637, 15.95225465321139, 0.31997818524223115]

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 15))

label_obe = 'NEGATIVO', 'POSITIVO','SE IGNORA'
label_dia = 'NEGATIVO', 'POSITIVO','SE IGNORA'

ax[0].pie(porcentaje_obesidad, labels=label_neumo, autopct='%1.2f%%') 
ax[0].set_title('OBESIDAD', fontsize=16)

ax[1].pie(porcentaje_diabetes, labels=label_asma, autopct='%1.2f%%')
ax[1].set_title('DIABETES', fontsize=16)
# Out:
# Text(0.5, 1.0, 'DIABETES')

# %%
#df_virus["Defuncion"] = df_virus.apply(lambda x: "0" if (x["FECHA_DEF"]) == '9999-99-99' else "1", axis=1)
#df_virus.head()

# %% [markdown]
# ## Entidades

# %%
entidades={
1:'Aguascalientes',
2:'Baja California',
3:'Baja California Sur',
4:'Campeche',
5:'Coahuila',
6:'Colima',
7:'Chiapas',
8:'Chihuahua',
9:'Ciudad De Mexico',
10:'Durango',
11:'Guanajuato',
12:'Guerrero',
13:'Hidalgo',
14:'Jalisco',
15:'Mexico',
16:'Michoacan',
17:'Morelos',
18:'Nayarit',
19:'Nuevoleon',
20:'Oaxaca',
21:'Puebla',
22:'Queretaro',
23:'Quintana Roo',
24:'Sanluispotosi',
25:'Sinaloa',
26:'Sonora',
27:'Tabasco',
28:'Tamaulipas',
29:'Tlaxcala',
30:'Veracruz',
31:'Yucatan',
32:'Zacatecas',
36:'Estados Unidos Mexicanos',
97:'No Aplica',
98:'Se Ignora',
99:'No Especificado'}

df_virus.head()
# Out:
#    ORIGEN  SECTOR  SEXO  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 0       2       3     1           25              6              2
# 1       2       4     1            1              1              1
# 2       2       4     2            9              2              2
# 3       2       3     1           27              4              1
# 4       2       4     1           26             55              2
#
#   FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  NEUMONIA  ...  EPOC  ASMA  \
# 0    09/06/2020     06/06/2020  16/06/2020         1  ...     2     2
# 1    23/04/2020     13/04/2020  9999-99-99         2  ...     2     2
# 2    29/04/2020     22/04/2020  03/05/2020         1  ...     2     2
# 3    25/06/2020     20/06/2020  9999-99-99         1  ...     2     2
# 4    30/03/2020     27/03/2020  9999-99-99         1  ...     2     2
#
#    INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0         2             2         2               2         2              2
# 1         2             2         2               2         2              2
# 2         2             1         2               2         2              2
# 3         2             1         2               2         2              2
# 4         2             1         2               2         2              2
#
#    TABAQUISMO  RESULTADO
# 0           2          1
# 1           2          1
# 2           2          1
# 3           2          1
# 4           2          1
#
# [5 rows x 24 columns]

# %%
entidades
# Out:
# {1: 'Aguascalientes',
#  2: 'Baja California',
#  3: 'Baja California Sur',
#  4: 'Campeche',
#  5: 'Coahuila',
#  6: 'Colima',
#  7: 'Chiapas',
#  8: 'Chihuahua',
#  9: 'Ciudad De Mexico',
#  10: 'Durango',
#  11: 'Guanajuato',
#  12: 'Guerrero',
#  13: 'Hidalgo',
#  14: 'Jalisco',
#  15: 'Mexico',
#  16: 'Michoacan',
#  17: 'Morelos',
#  18: 'Nayarit',
#  19: 'Nuevoleon',
#  20: 'Oaxaca',
#  21: 'Puebla',
#  22: 'Queretaro',
#  23: 'Quintana Roo',
#  24: 'Sanluispotosi',
#  25: 'Sinaloa',
#  26: 'Sonora',
#  27: 'Tabasco',
#  28: 'Tamaulipas',
#  29: 'Tlaxcala',
#  30: 'Veracruz',
#  31: 'Yucatan',
#  32: 'Zacatecas',
#  36: 'Estados Unidos Mexicanos',
#  97: 'No Aplica',
#  98: 'Se Ignora',
#  99: 'No Especificado'}

# %%
df_virus['ENTIDAD_RES'] =df_virus['ENTIDAD_RES'].map(entidades)

# %%
df_virus.head()
# Out:
#    ORIGEN  SECTOR  SEXO       ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 0       2       3     1           Sinaloa              6              2
# 1       2       4     1    Aguascalientes              1              1
# 2       2       4     2  Ciudad De Mexico              2              2
# 3       2       3     1           Tabasco              4              1
# 4       2       4     1            Sonora             55              2
#
#   FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  NEUMONIA  ...  EPOC  ASMA  \
# 0    09/06/2020     06/06/2020  16/06/2020         1  ...     2     2
# 1    23/04/2020     13/04/2020  9999-99-99         2  ...     2     2
# 2    29/04/2020     22/04/2020  03/05/2020         1  ...     2     2
# 3    25/06/2020     20/06/2020  9999-99-99         1  ...     2     2
# 4    30/03/2020     27/03/2020  9999-99-99         1  ...     2     2
#
#    INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0         2             2         2               2         2              2
# 1         2             2         2               2         2              2
# 2         2             1         2               2         2              2
# 3         2             1         2               2         2              2
# 4         2             1         2               2         2              2
#
#    TABAQUISMO  RESULTADO
# 0           2          1
# 1           2          1
# 2           2          1
# 3           2          1
# 4           2          1
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Infectados y Muertes por Edad

# %%
df_edad=df_virus.loc[df_virus['RESULTADO'] == 1]
plt.hist(df_edad['EDAD'], bins=20, range=(0,100), histtype='bar', ec='black')
plt.xlabel('Edad')
plt.ylabel('Número de infectados')
plt.show()

# %%
df_edad= df_virus.loc[(df_virus['RESULTADO'] == 1) & (df_virus['FECHA_DEF'] != '9999-99-99') & (df_virus.FECHA_DEF.notnull())]
plt.hist(df_edad['EDAD'], bins=20, range=(0,100), histtype='bar', ec='black')
plt.xlabel('Edad')
plt.ylabel('Muertes Por Edad')
plt.show()

# %% [markdown]
# ## % Entidades con contagios

# %%
ENTIDAD_INFECTADOS=df_virus.loc[(df_virus['RESULTADO'] == 1)]
ENTIDAD_INFECTADOS=ENTIDAD_INFECTADOS['ENTIDAD_RES'].value_counts()

# %%
ENTIDAD_INFECTADOS.plot(kind='pie',shadow=None,autopct='%1.1f%%',figsize=(15,10),labels=None,pctdistance=1.07)
plt.title('Infectados Por Entidad',loc="right",fontsize='30')
plt.legend(labels=ENTIDAD_INFECTADOS.index,loc='lower left',bbox_to_anchor=(-0.3, 0., 0.5, 0.5))
plt.axis('equal')
# Out:
# (-1.1011477051629806,
#  1.1000546527604176,
#  -1.1007304162969407,
#  1.108336486536686)

# %%
ENTIDAD_DEFUNCIONES=df_virus.loc[(df_virus['RESULTADO'] == 1) & (df_virus['FECHA_DEF'] != '9999-99-99') & (df_virus.FECHA_DEF.notnull())]
ENTIDAD_DEFUNCIONES=ENTIDAD_DEFUNCIONES['ENTIDAD_RES'].value_counts()

# %%
ENTIDAD_DEFUNCIONES.plot(kind='pie',shadow=None,autopct='%1.1f%%',figsize=(15,10),labels=None,pctdistance=1.07)
plt.title('Defunciones Por Entidad',loc="right",fontsize='30')
plt.legend(labels=ENTIDAD_DEFUNCIONES.index,loc='lower left',bbox_to_anchor=(-0.3, 0., 0.5, 0.5))
plt.axis('equal')
# Out:
# (-1.1009182532450204,
#  1.1000437266587821,
#  -1.10058806932925,
#  1.1068423076966156)

# %%
positivos = df_virus.loc[df_virus['RESULTADO'] == 1]
muertes = df_virus.loc[(df_virus['RESULTADO'] == 1) & (df_virus['FECHA_DEF'] != '9999-99-99') & (df_virus.FECHA_DEF.notnull())]
estados=df_virus.groupby(['ENTIDAD_RES'])
estados=estados['ENTIDAD_RES']
estados.head()
positivos.head()
# Out:
#    ORIGEN  SECTOR  SEXO       ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 0       2       3     1           Sinaloa              6              2
# 1       2       4     1    Aguascalientes              1              1
# 2       2       4     2  Ciudad De Mexico              2              2
# 3       2       3     1           Tabasco              4              1
# 4       2       4     1            Sonora             55              2
#
#   FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  NEUMONIA  ...  EPOC  ASMA  \
# 0    09/06/2020     06/06/2020  16/06/2020         1  ...     2     2
# 1    23/04/2020     13/04/2020  9999-99-99         2  ...     2     2
# 2    29/04/2020     22/04/2020  03/05/2020         1  ...     2     2
# 3    25/06/2020     20/06/2020  9999-99-99         1  ...     2     2
# 4    30/03/2020     27/03/2020  9999-99-99         1  ...     2     2
#
#    INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0         2             2         2               2         2              2
# 1         2             2         2               2         2              2
# 2         2             1         2               2         2              2
# 3         2             1         2               2         2              2
# 4         2             1         2               2         2              2
#
#    TABAQUISMO  RESULTADO
# 0           2          1
# 1           2          1
# 2           2          1
# 3           2          1
# 4           2          1
#
# [5 rows x 24 columns]

# %% [markdown]
# # Sectores de salud

# %%
sectores={
1:'CRUZ ROJA',
2:'DIF',
3:'ESTATAL',
4:'IMSS',
5:'IMSS-BIENESTAR',
6:'ISSSTE',
7:'MUNICIPAL',
8:'PEMEX',
9:'PRIVADA',
10:'SEDENA',
11:'SEMAR',
12:'SSA',
13:'UNIVERSITARIO',
99:'NO ESPECIFICADO'}
sectores
# Out:
# {1: 'CRUZ ROJA',
#  2: 'DIF',
#  3: 'ESTATAL',
#  4: 'IMSS',
#  5: 'IMSS-BIENESTAR',
#  6: 'ISSSTE',
#  7: 'MUNICIPAL',
#  8: 'PEMEX',
#  9: 'PRIVADA',
#  10: 'SEDENA',
#  11: 'SEMAR',
#  12: 'SSA',
#  13: 'UNIVERSITARIO',
#  99: 'NO ESPECIFICADO'}

# %%
df_virus['SECTOR'] =df_virus['SECTOR'].map(sectores)

# %%
SECTOR_INFECTADOS=df_virus.loc[(df_virus['RESULTADO'] == 1)]
SECTOR_INFECTADOS=SECTOR_INFECTADOS['SECTOR'].value_counts()
SECTOR_INFECTADOS.head()
# Out:
# SSA        257392
# IMSS       150156
# ISSSTE      20503
# PRIVADA     14214
# ESTATAL     10384
# Name: SECTOR, dtype: int64

# %%
SECTOR_INFECTADOS.plot(kind='barh',figsize=(10,6))
plt.ylabel('Sector Salud')
plt.xlabel('Numero De Infectados')
plt.title('Infectados Atendidos En Los Sectores De Salud')
for index,value in enumerate(SECTOR_INFECTADOS):
    label=format(int(value),',')
    plt.annotate(label,xy=(value,index),color='black')
plt.show()

# %%
SECTOR_DEFUNCIONES=df_virus.loc[(df_virus['RESULTADO'] == 1) & (df_virus['FECHA_DEF'] != '9999-99-99') & (df_virus.FECHA_DEF.notnull())]
SECTOR_DEFUNCIONES=SECTOR_DEFUNCIONES['SECTOR'].value_counts()
SECTOR_DEFUNCIONES.head()
# Out:
# IMSS       28489
# SSA        15520
# ISSSTE      3557
# ESTATAL     1225
# PEMEX        842
# Name: SECTOR, dtype: int64

# %%
SECTOR_DEFUNCIONES.plot(kind='barh',figsize=(10,6))
plt.ylabel('Sector Salud')
plt.xlabel('Numero De Muertes')
plt.title('Muertes Por Sectores De Salud')
for index,value in enumerate(SECTOR_DEFUNCIONES):
    label=format(int(value),',')
    plt.annotate(label,xy=(value,index),color='black')
plt.show()

# %%
df_virus.head()
# Out:
#    ORIGEN   SECTOR  SEXO       ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 0       2  ESTATAL     1           Sinaloa              6              2
# 1       2     IMSS     1    Aguascalientes              1              1
# 2       2     IMSS     2  Ciudad De Mexico              2              2
# 3       2  ESTATAL     1           Tabasco              4              1
# 4       2     IMSS     1            Sonora             55              2
#
#   FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  NEUMONIA  ...  EPOC  ASMA  \
# 0    09/06/2020     06/06/2020  16/06/2020         1  ...     2     2
# 1    23/04/2020     13/04/2020  9999-99-99         2  ...     2     2
# 2    29/04/2020     22/04/2020  03/05/2020         1  ...     2     2
# 3    25/06/2020     20/06/2020  9999-99-99         1  ...     2     2
# 4    30/03/2020     27/03/2020  9999-99-99         1  ...     2     2
#
#    INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0         2             2         2               2         2              2
# 1         2             2         2               2         2              2
# 2         2             1         2               2         2              2
# 3         2             1         2               2         2              2
# 4         2             1         2               2         2              2
#
#    TABAQUISMO  RESULTADO
# 0           2          1
# 1           2          1
# 2           2          1
# 3           2          1
# 4           2          1
#
# [5 rows x 24 columns]

# %% [markdown]
# # Mapa de México

# %%
mexico_geo=r'estados.json'

# %%
df_virus.head()
# Out:
#    ORIGEN   SECTOR  SEXO       ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# 0       2  ESTATAL     1           Sinaloa              6              2
# 1       2     IMSS     1    Aguascalientes              1              1
# 2       2     IMSS     2  Ciudad De Mexico              2              2
# 3       2  ESTATAL     1           Tabasco              4              1
# 4       2     IMSS     1            Sonora             55              2
#
#   FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  NEUMONIA  ...  EPOC  ASMA  \
# 0    09/06/2020     06/06/2020  16/06/2020         1  ...     2     2
# 1    23/04/2020     13/04/2020  9999-99-99         2  ...     2     2
# 2    29/04/2020     22/04/2020  03/05/2020         1  ...     2     2
# 3    25/06/2020     20/06/2020  9999-99-99         1  ...     2     2
# 4    30/03/2020     27/03/2020  9999-99-99         1  ...     2     2
#
#    INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0         2             2         2               2         2              2
# 1         2             2         2               2         2              2
# 2         2             1         2               2         2              2
# 3         2             1         2               2         2              2
# 4         2             1         2               2         2              2
#
#    TABAQUISMO  RESULTADO
# 0           2          1
# 1           2          1
# 2           2          1
# 3           2          1
# 4           2          1
#
# [5 rows x 24 columns]

# %%
m = folium.Map(
    location=[24.5627966,-106.5617301],
    tiles='Mapbox Bright',
    zoom_start=5  # Limited levels of zoom for free Mapbox tiles.
)

folium.GeoJson(
    mexico_geo,
    name='geojson'
).add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ![](Mapa001.jpg)

# %%
df_ENTIDAD_DEFUNCIONES = ENTIDAD_DEFUNCIONES.to_frame().reset_index()
df_ENTIDAD_DEFUNCIONES
# Out:
#                   index  ENTIDAD_RES
# 0                Mexico         8663
# 1      Ciudad De Mexico         7502
# 2              Veracruz         3045
# 3       Baja California         2774
# 4                Puebla         2699
# 5               Sinaloa         2346
# 6                Sonora         2222
# 7               Tabasco         2129
# 8               Jalisco         1712
# 9              Guerrero         1464
# 10            Nuevoleon         1383
# 11           Tamaulipas         1227
# 12           Guanajuato         1178
# 13              Hidalgo         1137
# 14         Quintana Roo         1099
# 15               Oaxaca         1035
# 16              Chiapas         1003
# 17              Yucatan          977
# 18            Chihuahua          959
# 19              Morelos          868
# 20            Michoacan          847
# 21             Coahuila          819
# 22             Tlaxcala          769
# 23        Sanluispotosi          601
# 24             Campeche          571
# 25            Queretaro          492
# 26              Nayarit          434
# 27              Durango          332
# 28            Zacatecas          304
# 29       Aguascalientes          272
# 30               Colima          239
# 31  Baja California Sur          209

# %%
df_ENTIDAD_INFECTADOS = ENTIDAD_INFECTADOS.to_frame().reset_index()
len(df_ENTIDAD_INFECTADOS)
# Out:
# 32

# %%
tooltip_text = []
for idx in range(32):
    tooltip_text.append(str(df_ENTIDAD_INFECTADOS['ENTIDAD_RES'])
#tooltip_text

for idx in range(len(tooltip_text)):
    mexico_geo['Feature'][idx]['properties']['Num'] = tooltip_text[idx]

# %%
m=folium.Map(location=[24.5627966,-106.5617301],zoom_start=5,tiles='Mapbox Bright')
choropleth = folium.Choropleth(
geo_data=mexico_geo,
data=df_ENTIDAD_INFECTADOS,
columns=['index','ENTIDAD_RES'],
key_on='properties.state_name',
fill_color='RdPu',
fill_opacity=0.8,
line_opacity=0.2,
legend_name='Defunciones Por Estado',
highlight = True ).add_to(m)
folium.LayerControl(collapsed=True)

choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(['state_name'],labels=False)
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ![](Mapa002.jpg)

# %%
m=folium.Map(location=[24.5627966,-106.5617301],zoom_start=5,tiles='Mapbox Bright')
choropleth = folium.Choropleth(
geo_data=mexico_geo,
data=df_ENTIDAD_DEFUNCIONES,
columns=['index','ENTIDAD_RES'],
key_on='properties.state_name',
fill_color='RdPu',
fill_opacity=0.8,
line_opacity=0.2,
legend_name='Defunciones Por Estado',
highlight = True ).add_to(m)
folium.LayerControl(collapsed=True)

choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(['state_name'],labels=False)
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ![](Mapa003.jpg)

# %%
#dgo_map= folium.Map(location= [24.035976,-104.640303],
#                        zoom_start=12)
#dgo_map

# %% [markdown]
# # Correlacion entre enfermedades y COVID-19

# %%
df_correlacion=pd.read_csv('200807COVID19MEXICO.csv', encoding = "ISO-8859-1")

# %%
df_correlacion.drop(['EDAD','ORIGEN','SECTOR','SEXO','ENTIDAD_RES','MUNICIPIO_RES','TIPO_PACIENTE','NACIONALIDAD',
                     'FECHA_INGRESO','FECHA_SINTOMAS','FECHA_DEF','OTRA_COM','EMBARAZO','RESULTADO','HABLA_LENGUA_INDIG',
                     'ENTIDAD_UM','FECHA_ACTUALIZACION','ID_REGISTRO','ENTIDAD_NAC','MIGRANTE','PAIS_NACIONALIDAD',
                     'PAIS_ORIGEN','INTUBADO','UCI','OTRO_CASO'],axis=1,inplace=True)

# %%
df_correlacion.head()
# Out:
#    NEUMONIA  DIABETES  EPOC  ASMA  INMUSUPR  HIPERTENSION  CARDIOVASCULAR  \
# 0         1         2     2     2         2             2               2
# 1         2         2     2     2         2             2               2
# 2         1         1     2     2         2             1               2
# 3         1         2     2     2         2             1               2
# 4         1         2     2     2         2             1               2
#
#    OBESIDAD  RENAL_CRONICA  TABAQUISMO
# 0         2              2           2
# 1         2              2           2
# 2         2              2           2
# 3         2              2           2
# 4         2              2           2

# %%
df_correlacion.corr(method ='pearson')
# Out:
#                 NEUMONIA  DIABETES      EPOC      ASMA  INMUSUPR  \
# NEUMONIA        1.000000 -0.002239 -0.008882 -0.010490 -0.011396
# DIABETES       -0.002239  1.000000  0.832761  0.833724  0.794312
# EPOC           -0.008882  0.832761  1.000000  0.916455  0.870189
# ASMA           -0.010490  0.833724  0.916455  1.000000  0.885571
# INMUSUPR       -0.011396  0.794312  0.870189  0.885571  1.000000
# HIPERTENSION   -0.001300  0.839664  0.862923  0.871903  0.838812
# CARDIOVASCULAR -0.010349  0.814643  0.890705  0.901346  0.870565
# OBESIDAD       -0.008460  0.768819  0.834475  0.844543  0.814076
# RENAL_CRONICA  -0.008357  0.812831  0.890196  0.900581  0.868334
# TABAQUISMO     -0.010443  0.775478  0.845726  0.855354  0.824757
#
#                 HIPERTENSION  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# NEUMONIA           -0.001300       -0.010349 -0.008460      -0.008357
# DIABETES            0.839664        0.814643  0.768819       0.812831
# EPOC                0.862923        0.890705  0.834475       0.890196
# ASMA                0.871903        0.901346  0.844543       0.900581
# INMUSUPR            0.838812        0.870565  0.814076       0.868334
# HIPERTENSION        1.000000        0.865778  0.819706       0.862325
# CARDIOVASCULAR      0.865778        1.000000  0.848622       0.910224
# OBESIDAD            0.819706        0.848622  1.000000       0.856688
# RENAL_CRONICA       0.862325        0.910224  0.856688       1.000000
# TABAQUISMO          0.819206        0.858062  0.819275       0.867524
#
#                 TABAQUISMO
# NEUMONIA         -0.010443
# DIABETES          0.775478
# EPOC              0.845726
# ASMA              0.855354
# INMUSUPR          0.824757
# HIPERTENSION      0.819206
# CARDIOVASCULAR    0.858062
# OBESIDAD          0.819275
# RENAL_CRONICA     0.867524
# TABAQUISMO        1.000000

# %%
NEU = df_correlacion[(df_correlacion.NEUMONIA == 1)]

# %%
NEU.corr(method='pearson')
# Out:
#                 NEUMONIA  DIABETES      EPOC      ASMA  INMUSUPR  \
# NEUMONIA             NaN       NaN       NaN       NaN       NaN
# DIABETES             NaN  1.000000  0.783752  0.792952  0.736350
# EPOC                 NaN  0.783752  1.000000  0.905213  0.826565
# ASMA                 NaN  0.792952  0.905213  1.000000  0.857139
# INMUSUPR             NaN  0.736350  0.826565  0.857139  1.000000
# HIPERTENSION         NaN  0.833712  0.818242  0.829250  0.775167
# CARDIOVASCULAR       NaN  0.756663  0.842124  0.856261  0.802996
# OBESIDAD             NaN  0.651244  0.721611  0.741057  0.687333
# RENAL_CRONICA        NaN  0.764713  0.854453  0.875161  0.817020
# TABAQUISMO           NaN  0.735762  0.824161  0.836790  0.780944
#
#                 HIPERTENSION  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# NEUMONIA                 NaN             NaN       NaN            NaN
# DIABETES            0.833712        0.756663  0.651244       0.764713
# EPOC                0.818242        0.842124  0.721611       0.854453
# ASMA                0.829250        0.856261  0.741057       0.875161
# INMUSUPR            0.775167        0.802996  0.687333       0.817020
# HIPERTENSION        1.000000        0.801108  0.687512       0.804139
# CARDIOVASCULAR      0.801108        1.000000  0.722133       0.874069
# OBESIDAD            0.687512        0.722133  1.000000       0.755355
# RENAL_CRONICA       0.804139        0.874069  0.755355       1.000000
# TABAQUISMO          0.770911        0.819278  0.714361       0.844541
#
#                 TABAQUISMO
# NEUMONIA               NaN
# DIABETES          0.735762
# EPOC              0.824161
# ASMA              0.836790
# INMUSUPR          0.780944
# HIPERTENSION      0.770911
# CARDIOVASCULAR    0.819278
# OBESIDAD          0.714361
# RENAL_CRONICA     0.844541
# TABAQUISMO        1.000000

# %%
DIAB = df_correlacion[(df_correlacion.DIABETES == 1)]

# %%
DIAB.corr(method='pearson')
# Out:
#                 NEUMONIA  DIABETES      EPOC      ASMA  INMUSUPR  \
# NEUMONIA        1.000000       NaN -0.006498 -0.015873 -0.017688
# DIABETES             NaN       NaN       NaN       NaN       NaN
# EPOC           -0.006498       NaN  1.000000  0.647627  0.514448
# ASMA           -0.015873       NaN  0.647627  1.000000  0.584005
# INMUSUPR       -0.017688       NaN  0.514448  0.584005  1.000000
# HIPERTENSION    0.008759       NaN  0.399063  0.464045  0.369646
# CARDIOVASCULAR -0.013225       NaN  0.512941  0.570653  0.459024
# OBESIDAD       -0.023119       NaN  0.324884  0.367444  0.292823
# RENAL_CRONICA  -0.005439       NaN  0.505569  0.580089  0.460552
# TABAQUISMO     -0.016918       NaN  0.419993  0.448162  0.367775
#
#                 HIPERTENSION  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# NEUMONIA            0.008759       -0.013225 -0.023119      -0.005439
# DIABETES                 NaN             NaN       NaN            NaN
# EPOC                0.399063        0.512941  0.324884       0.505569
# ASMA                0.464045        0.570653  0.367444       0.580089
# INMUSUPR            0.369646        0.459024  0.292823       0.460552
# HIPERTENSION        1.000000        0.425916  0.323533       0.425226
# CARDIOVASCULAR      0.425916        1.000000  0.394312       0.597825
# OBESIDAD            0.323533        0.394312  1.000000       0.412931
# RENAL_CRONICA       0.425226        0.597825  0.412931       1.000000
# TABAQUISMO          0.324255        0.469474  0.359251       0.489408
#
#                 TABAQUISMO
# NEUMONIA         -0.016918
# DIABETES               NaN
# EPOC              0.419993
# ASMA              0.448162
# INMUSUPR          0.367775
# HIPERTENSION      0.324255
# CARDIOVASCULAR    0.469474
# OBESIDAD          0.359251
# RENAL_CRONICA     0.489408
# TABAQUISMO        1.000000

# %%
EP = df_correlacion[(df_correlacion.EPOC == 1)]

# %%
EP.corr(method='pearson')
# Out:
#                 NEUMONIA  DIABETES  EPOC      ASMA  INMUSUPR  HIPERTENSION  \
# NEUMONIA        1.000000 -0.010345   NaN -0.012384 -0.014683      0.004618
# DIABETES       -0.010345  1.000000   NaN  0.433227  0.417548      0.324629
# EPOC                 NaN       NaN   NaN       NaN       NaN           NaN
# ASMA           -0.012384  0.433227   NaN  1.000000  0.597025      0.387319
# INMUSUPR       -0.014683  0.417548   NaN  0.597025  1.000000      0.426481
# HIPERTENSION    0.004618  0.324629   NaN  0.387319  0.426481      1.000000
# CARDIOVASCULAR -0.017385  0.442475   NaN  0.510488  0.446341      0.376639
# OBESIDAD       -0.018482  0.373997   NaN  0.444841  0.480920      0.225665
# RENAL_CRONICA  -0.011391  0.426023   NaN  0.568323  0.468132      0.324411
# TABAQUISMO     -0.018909  0.393909   NaN  0.494280  0.395367      0.275732
#
#                 CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO
# NEUMONIA             -0.017385 -0.018482      -0.011391   -0.018909
# DIABETES              0.442475  0.373997       0.426023    0.393909
# EPOC                       NaN       NaN            NaN         NaN
# ASMA                  0.510488  0.444841       0.568323    0.494280
# INMUSUPR              0.446341  0.480920       0.468132    0.395367
# HIPERTENSION          0.376639  0.225665       0.324411    0.275732
# CARDIOVASCULAR        1.000000  0.435791       0.544072    0.461251
# OBESIDAD              0.435791  1.000000       0.488382    0.387841
# RENAL_CRONICA         0.544072  0.488382       1.000000    0.444679
# TABAQUISMO            0.461251  0.387841       0.444679    1.000000

# %%
import seaborn as sns
NEUMO = NEU[NEU.columns].astype(float)
DIABE = DIAB[DIAB.columns].astype(float)

# %% [markdown]
# ### NEUMONIA

# %%
wcorr = NEUMO.corr()
sns.heatmap(wcorr)

# %% [markdown]
# ### DIABETES

# %%
wcorr = DIABE.corr()
sns.heatmap(wcorr)

# %% [markdown]
# ### EPOC

# %%
wcorr = EP.corr()
sns.heatmap(wcorr)
